# %%
# ----- Libraries ----- #

# This is the main Library that allows us to work with Neural Networks
import tensorflow as tf


# For graph plotting
import matplotlib.pyplot as plt
from tensorflow.math import confusion_matrix

# For dataset manipulation
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np

# For visualizing more complex graphs
import seaborn as sns

# Miscellaneous Libraries
import os

# %%
raw_train_dataset = pd.read_csv("Boston_House_Price.csv")
processed_dataset = raw_train_dataset.copy()
raw_train_dataset

# %%
# prompt: Using dataframe raw_train_dataset: i want to change the NOX column from the dataframe to have normalized values and then do this:
# As this values increase, the price value goes down, so i want you to make sure at the normalization that the higher values of nox are the lower ones and the lower values are the highest ones

# Normalize the 'NOX' column so that higher values are lower and lower values are higher
processed_dataset['NOX'] = (processed_dataset['NOX'].max() - processed_dataset['NOX']) / (processed_dataset['NOX'].max() - processed_dataset['NOX'].min())

# %%
processed_dataset['CRIM'] = (processed_dataset['CRIM'].max() - processed_dataset['CRIM']) / (processed_dataset['CRIM'].max() - processed_dataset['CRIM'].min())

# %%
processed_dataset['TAX'] = (processed_dataset['TAX'].max() - processed_dataset['TAX']) / (processed_dataset['TAX'].max() - processed_dataset['TAX'].min())

# %%
### --- MIN-MAX NORMALIZATION ---
# To normalize, first we have to get the maximum and minimum value
max_zn = np.max(processed_dataset['ZN'])
min_zn = np.min(processed_dataset['ZN'])
print('Max ZN level: {}\t Min ZN level: {}'.format(max_zn, min_zn))

# Remember the .apply() function? We can use that here to normalize EVERY value of the column!
# But first we have to define our normalization function
def normalize_zn(x):
  return (x-min_zn)/(max_zn-min_zn)

# Now, lets normalize every value of the column!
processed_dataset['ZN'] = processed_dataset['ZN'].apply(normalize_zn)

# And finally, lets check that all the possible UNIQUE values that the column has are indeed between 0 and 1
processed_dataset['ZN'].unique()
# Out:
# Max ZN level: 100.0	 Min ZN level: 0.0
# array([0.18 , 0.   , 0.125, 0.75 , 0.21 , 0.9  , 0.85 , 1.   , 0.25 ,
#        0.175, 0.8  , 0.28 , 0.45 , 0.6  , 0.95 , 0.825, 0.3  , 0.22 ,
#        0.2  , 0.4  , 0.55 , 0.525, 0.7  , 0.34 , 0.33 , 0.35 ])

# %%
processed_dataset
# Out:
#          CRIM    ZN  INDUS       NOX     RM  AGE     DIS       TAX  PTRATIO  \
# 0    1.000000  0.18   2.31  0.685185  6.575    0  4.0900  0.791985     15.3
# 1    0.999764  0.00   7.07  0.827160  6.421    0  4.9671  0.895038     17.8
# 2    0.999764  0.00   7.07  0.827160  7.185    0  4.9671  0.895038     17.8
# 3    0.999707  0.00   2.18  0.849794  6.998    1  6.0622  0.933206     18.7
# 4    0.999295  0.00   2.18  0.849794  7.147    0  6.0622  0.933206     18.7
# ..        ...   ...    ...       ...    ...  ...     ...       ...      ...
# 501  0.999367  0.00  11.93  0.613169  6.593    0  2.4786  0.835878     21.0
# 502  0.999562  0.00  11.93  0.613169  6.120    0  2.2875  0.835878     21.0
# 503  0.999388  0.00  11.93  0.613169  6.976    0  2.1675  0.835878     21.0
# 504  0.998839  0.00  11.93  0.613169  6.794    0  2.3889  0.835878     21.0
# 505  0.999538  0.00  11.93  0.613169  6.030    0  2.5050  0.835878     21.0
#
#      PRICE
# 0     24.0
# 1     21.6
# 2     34.7
# 3     33.4
# 4     36.2
# ..     ...
# 501   22.4
# 502   20.6
# 503   23.9
# 504   22.0
# 505   11.9
#
# [506 rows x 10 columns]

# %%
# prompt: Using dataframe raw_train_dataset: i want the values from the column age to be 1 when te value is lower than 50 and 0 when is higher

# Replace values in 'AGE' column based on condition
processed_dataset['AGE'] = processed_dataset['AGE'].apply(lambda x: 1 if x < 50 else 0)

# %%
# prompt: Using dataframe raw_train_dataset: delete the column CHAS

# Drop the 'CHAS' column from the DataFrame
processed_dataset = processed_dataset.drop('CHAS', axis=1)
processed_dataset = processed_dataset.drop('B', axis=1)
processed_dataset = processed_dataset.drop('LSTAT', axis=1)
processed_dataset = processed_dataset.drop('RAD', axis=1)

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Split dataset into training and testing
train, test = train_test_split(processed_dataset, test_size=0.2)

# Separate into features and target
independent_variables = list(processed_dataset.columns)
independent_variables.remove('PRICE')
dependent_variables = ['PRICE']

train_set = train[independent_variables]
train_target = train[dependent_variables]
test_set = test[independent_variables]
test_target = test[dependent_variables]

# Build regression model
normal_model = tf.keras.models.Sequential([
    tf.keras.layers.InputLayer(input_shape=(len(independent_variables),)),
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dense(units=32, activation='relu'),
    tf.keras.layers.Dense(units=1)  # Linear activation for regression
])

# Compile with appropriate regression loss
normal_model.compile(
    loss='mse',
    optimizer='adam',
    metrics=[tf.keras.metrics.MeanAbsoluteError()]
)

# Train model
normal_model.fit(
    train_set,
    train_target,
    epochs=150,
    batch_size=256,
    validation_split=0.2,
)

# Predict and evaluate
predictions = normal_model.predict(test_set).flatten()
true_values = test_target.values.flatten()

# Metrics
mae = mean_absolute_error(true_values, predictions)
rmse = np.sqrt(mean_squared_error(true_values, predictions))
r2 = r2_score(true_values, predictions)
n = test_set.shape[0]
k = test_set.shape[1]
adjusted_r2 = 1 - (1 - r2) * (n - 1) / (n - k - 1)

# Print evaluation results
print(f"MAE: {mae:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"R²: {r2:.4f}")
print(f"Adjusted R²: {adjusted_r2:.4f}")
# Out:
# Epoch 1/150
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 477ms/step - loss: 601.9394 - mean_absolute_error: 22.6770 - val_loss: 587.1639 - val_mean_absolute_error: 22.5519
# Epoch 2/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 586.1513 - mean_absolute_error: 22.3071 - val_loss: 571.7228 - val_mean_absolute_error: 22.1867
# Epoch 3/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 574.9118 - mean_absolute_error: 22.0270 - val_loss: 555.1074 - val_mean_absolute_error: 21.7863
# Epoch 4/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 560.8936 - mean_absolute_error: 21.6737 - val_loss: 536.4370 - val_mean_absolute_error: 21.3386
# Epoch 5/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 538.5806 - mean_absolute_error: 21.1309 - val_loss: 511.5604 - val_mean_absolute_error: 20.7270
# Epoch 6/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 516.9258 - mean_absolute_error: 20.5981 - val_loss: 480.1385 - val_mean_absolute_error: 19.9270
# Epoch 7/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 479.0891 - mean_absolute_error: 19.6441 - val_loss: 442.3144 - val_mean_absolute_error: 18.9234
# Epoch 8/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 450.9106 - mean_absolute_error: 18.8243 - val_loss: 398.3398 - val_mean_absolute_error: 17.7067
# Epoch 9/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 398.8497 - mean_absolute_error: 17.4072 - val_loss: 347.9007 - val_mean_absolute_error: 16.1903
# Epoch 10/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 359.9400 - mean_absolute_error: 16.0658 - val_loss: 291.3895 - val_mean_absolute_error: 14.3318
# Epoch 11/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 299.8968 - mean_absolute_error: 14.2457 - val_loss: 232.1058 - val_mean_absolute_error: 12.2756
# Epoch 12/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 234.8493 - mean_absolute_error: 12.0814 - val_loss: 175.2557 - val_mean_absolute_error: 10.4073
# Epoch 13/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 188.3727 - mean_absolute_error: 10.3157 - val_loss: 131.2870 - val_mean_absolute_error: 8.5983
# Epoch 14/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 148.2768 - mean_absolute_error: 8.9892 - val_loss: 114.6967 - val_mean_absolute_error: 8.1572
# Epoch 15/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 130.7117 - mean_absolute_error: 8.6450 - val_loss: 129.5383 - val_mean_absolute_error: 9.2183
# Epoch 16/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 148.3900 - mean_absolute_error: 9.7967 - val_loss: 148.9074 - val_mean_absolute_error: 10.1259
# Epoch 17/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 162.6314 - mean_absolute_error: 10.5875 - val_loss: 141.8269 - val_mean_absolute_error: 9.8475
# Epoch 18/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 155.2747 - mean_absolute_error: 10.3041 - val_loss: 120.5299 - val_mean_absolute_error: 8.8620
# Epoch 19/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 135.2435 - mean_absolute_error: 9.3126 - val_loss: 104.4171 - val_mean_absolute_error: 7.8053
# Epoch 20/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 119.1153 - mean_absolute_error: 8.3521 - val_loss: 99.3198 - val_mean_absolute_error: 7.2184
# Epoch 21/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 112.1748 - mean_absolute_error: 7.7216 - val_loss: 100.1731 - val_mean_absolute_error: 7.0139
# Epoch 22/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 111.6171 - mean_absolute_error: 7.5866 - val_loss: 101.4518 - val_mean_absolute_error: 7.0216
# Epoch 23/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 110.8556 - mean_absolute_error: 7.4192 - val_loss: 100.3132 - val_mean_absolute_error: 6.9469
# Epoch 24/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 113.4640 - mean_absolute_error: 7.4630 - val_loss: 96.3617 - val_mean_absolute_error: 6.7193
# Epoch 25/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 102.7781 - mean_absolute_error: 7.1311 - val_loss: 91.0777 - val_mean_absolute_error: 6.4190
# Epoch 26/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 101.7829 - mean_absolute_error: 7.0263 - val_loss: 86.4388 - val_mean_absolute_error: 6.3250
# Epoch 27/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 94.3977 - mean_absolute_error: 6.8915 - val_loss: 84.7587 - val_mean_absolute_error: 6.4303
# Epoch 28/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 87.6569 - mean_absolute_error: 6.8814 - val_loss: 85.0830 - val_mean_absolute_error: 6.6048
# Epoch 29/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 90.2333 - mean_absolute_error: 7.1255 - val_loss: 85.4834 - val_mean_absolute_error: 6.7442
# Epoch 30/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 90.0558 - mean_absolute_error: 7.2403 - val_loss: 84.0627 - val_mean_absolute_error: 6.6502
# Epoch 31/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 87.0072 - mean_absolute_error: 7.0866 - val_loss: 81.7249 - val_mean_absolute_error: 6.3910
# Epoch 32/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 85.2340 - mean_absolute_error: 6.8103 - val_loss: 79.8417 - val_mean_absolute_error: 6.1463
# Epoch 33/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 81.6474 - mean_absolute_error: 6.5765 - val_loss: 78.9042 - val_mean_absolute_error: 5.9940
# Epoch 34/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 80.5985 - mean_absolute_error: 6.3622 - val_loss: 78.6587 - val_mean_absolute_error: 5.9311
# Epoch 35/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 77.9648 - mean_absolute_error: 6.2908 - val_loss: 78.5922 - val_mean_absolute_error: 5.9428
# Epoch 36/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 80.6893 - mean_absolute_error: 6.3415 - val_loss: 78.5984 - val_mean_absolute_error: 5.9844
# Epoch 37/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 76.5964 - mean_absolute_error: 6.1826 - val_loss: 78.8043 - val_mean_absolute_error: 6.0509
# Epoch 38/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 77.4460 - mean_absolute_error: 6.2164 - val_loss: 79.1118 - val_mean_absolute_error: 6.1353
# Epoch 39/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 73.5697 - mean_absolute_error: 6.1004 - val_loss: 79.3750 - val_mean_absolute_error: 6.2073
# Epoch 40/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 76.6215 - mean_absolute_error: 6.2008 - val_loss: 79.2668 - val_mean_absolute_error: 6.2216
# Epoch 41/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 76.7062 - mean_absolute_error: 6.2237 - val_loss: 78.6756 - val_mean_absolute_error: 6.1562
# Epoch 42/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 75.7741 - mean_absolute_error: 6.1953 - val_loss: 77.9706 - val_mean_absolute_error: 6.0696
# Epoch 43/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 72.4346 - mean_absolute_error: 6.0006 - val_loss: 77.4198 - val_mean_absolute_error: 6.0364
# Epoch 44/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 72.2279 - mean_absolute_error: 6.0014 - val_loss: 76.8985 - val_mean_absolute_error: 6.0405
# Epoch 45/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 68.8297 - mean_absolute_error: 5.9024 - val_loss: 76.4073 - val_mean_absolute_error: 6.0628
# Epoch 46/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 72.3724 - mean_absolute_error: 6.0154 - val_loss: 75.8768 - val_mean_absolute_error: 6.0816
# Epoch 47/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 70.3742 - mean_absolute_error: 5.9661 - val_loss: 75.2661 - val_mean_absolute_error: 6.0873
# Epoch 48/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 70.2862 - mean_absolute_error: 5.9477 - val_loss: 74.2855 - val_mean_absolute_error: 6.0350
# Epoch 49/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 70.6799 - mean_absolute_error: 5.9737 - val_loss: 73.2755 - val_mean_absolute_error: 5.9713
# Epoch 50/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 71.1580 - mean_absolute_error: 5.9636 - val_loss: 72.1916 - val_mean_absolute_error: 5.8686
# Epoch 51/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 68.3393 - mean_absolute_error: 5.8340 - val_loss: 71.3879 - val_mean_absolute_error: 5.8067
# Epoch 52/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 65.3562 - mean_absolute_error: 5.7245 - val_loss: 70.7822 - val_mean_absolute_error: 5.8208
# Epoch 53/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 66.0887 - mean_absolute_error: 5.7502 - val_loss: 70.5586 - val_mean_absolute_error: 5.9058
# Epoch 54/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 64.6711 - mean_absolute_error: 5.7477 - val_loss: 70.2943 - val_mean_absolute_error: 5.9496
# Epoch 55/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 64.5706 - mean_absolute_error: 5.7177 - val_loss: 69.3612 - val_mean_absolute_error: 5.8939
# Epoch 56/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 62.9442 - mean_absolute_error: 5.6693 - val_loss: 68.1522 - val_mean_absolute_error: 5.7826
# Epoch 57/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 61.9911 - mean_absolute_error: 5.5637 - val_loss: 67.0624 - val_mean_absolute_error: 5.6704
# Epoch 58/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 62.8036 - mean_absolute_error: 5.5029 - val_loss: 66.1559 - val_mean_absolute_error: 5.5904
# Epoch 59/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 61.7244 - mean_absolute_error: 5.4626 - val_loss: 65.3892 - val_mean_absolute_error: 5.5757
# Epoch 60/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 63.0122 - mean_absolute_error: 5.5134 - val_loss: 64.6075 - val_mean_absolute_error: 5.5795
# Epoch 61/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 59.3393 - mean_absolute_error: 5.3464 - val_loss: 63.7214 - val_mean_absolute_error: 5.5658
# Epoch 62/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 57.8555 - mean_absolute_error: 5.3648 - val_loss: 62.7359 - val_mean_absolute_error: 5.5408
# Epoch 63/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 57.2877 - mean_absolute_error: 5.3281 - val_loss: 61.4115 - val_mean_absolute_error: 5.4769
# Epoch 64/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 56.8501 - mean_absolute_error: 5.2527 - val_loss: 60.0366 - val_mean_absolute_error: 5.4177
# Epoch 65/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 55.6561 - mean_absolute_error: 5.2023 - val_loss: 58.5515 - val_mean_absolute_error: 5.3305
# Epoch 66/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 55.7317 - mean_absolute_error: 5.2122 - val_loss: 57.0199 - val_mean_absolute_error: 5.2397
# Epoch 67/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 53.2609 - mean_absolute_error: 5.0790 - val_loss: 55.5489 - val_mean_absolute_error: 5.1395
# Epoch 68/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 53.1868 - mean_absolute_error: 5.0144 - val_loss: 54.0998 - val_mean_absolute_error: 5.0090
# Epoch 69/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 53.5528 - mean_absolute_error: 4.9933 - val_loss: 52.8042 - val_mean_absolute_error: 4.9205
# Epoch 70/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 51.3093 - mean_absolute_error: 4.8922 - val_loss: 51.3731 - val_mean_absolute_error: 4.8888
# Epoch 71/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 47.0975 - mean_absolute_error: 4.7242 - val_loss: 50.0543 - val_mean_absolute_error: 4.9097
# Epoch 72/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 47.6937 - mean_absolute_error: 4.7483 - val_loss: 48.8317 - val_mean_absolute_error: 4.9349
# Epoch 73/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 46.0516 - mean_absolute_error: 4.6758 - val_loss: 47.5106 - val_mean_absolute_error: 4.9099
# Epoch 74/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 46.5240 - mean_absolute_error: 4.7148 - val_loss: 45.8647 - val_mean_absolute_error: 4.7683
# Epoch 75/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 41.8036 - mean_absolute_error: 4.4705 - val_loss: 44.2628 - val_mean_absolute_error: 4.5864
# Epoch 76/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 45.1668 - mean_absolute_error: 4.4697 - val_loss: 42.6275 - val_mean_absolute_error: 4.4570
# Epoch 77/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 40.2685 - mean_absolute_error: 4.1998 - val_loss: 40.4353 - val_mean_absolute_error: 4.3828
# Epoch 78/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 42.0674 - mean_absolute_error: 4.1714 - val_loss: 37.9737 - val_mean_absolute_error: 4.3423
# Epoch 79/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 39.5828 - mean_absolute_error: 4.1120 - val_loss: 36.1845 - val_mean_absolute_error: 4.3301
# Epoch 80/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 37.1049 - mean_absolute_error: 4.0451 - val_loss: 34.5580 - val_mean_absolute_error: 4.2644
# Epoch 81/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 37.9100 - mean_absolute_error: 3.9957 - val_loss: 33.2005 - val_mean_absolute_error: 4.2277
# Epoch 82/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 35.2867 - mean_absolute_error: 3.7834 - val_loss: 32.1319 - val_mean_absolute_error: 4.2238
# Epoch 83/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 35.8862 - mean_absolute_error: 3.7893 - val_loss: 31.1627 - val_mean_absolute_error: 4.1926
# Epoch 84/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 35.4813 - mean_absolute_error: 3.7449 - val_loss: 30.3462 - val_mean_absolute_error: 4.1592
# Epoch 85/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 36.1232 - mean_absolute_error: 3.7333 - val_loss: 29.8284 - val_mean_absolute_error: 4.1194
# Epoch 86/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 34.5845 - mean_absolute_error: 3.6382 - val_loss: 29.0311 - val_mean_absolute_error: 4.1604
# Epoch 87/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 33.7749 - mean_absolute_error: 3.6311 - val_loss: 29.3163 - val_mean_absolute_error: 4.2774
# Epoch 88/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 33.0469 - mean_absolute_error: 3.7001 - val_loss: 28.5890 - val_mean_absolute_error: 4.2331
# Epoch 89/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 33.4714 - mean_absolute_error: 3.6293 - val_loss: 28.1678 - val_mean_absolute_error: 4.1542
# Epoch 90/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 34.1072 - mean_absolute_error: 3.6375 - val_loss: 28.4553 - val_mean_absolute_error: 4.1583
# Epoch 91/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 35.1235 - mean_absolute_error: 3.6525 - val_loss: 28.0416 - val_mean_absolute_error: 4.1422
# Epoch 92/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 35.1234 - mean_absolute_error: 3.6564 - val_loss: 27.6971 - val_mean_absolute_error: 4.1499
# Epoch 93/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 28.6459 - mean_absolute_error: 3.4043 - val_loss: 28.1239 - val_mean_absolute_error: 4.2582
# Epoch 94/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 30.6283 - mean_absolute_error: 3.5294 - val_loss: 28.2367 - val_mean_absolute_error: 4.2840
# Epoch 95/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 33.4128 - mean_absolute_error: 3.6222 - val_loss: 27.4528 - val_mean_absolute_error: 4.1217
# Epoch 96/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 34.2199 - mean_absolute_error: 3.5544 - val_loss: 28.4011 - val_mean_absolute_error: 4.0774
# Epoch 97/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 32.7102 - mean_absolute_error: 3.5581 - val_loss: 27.2825 - val_mean_absolute_error: 4.0752
# Epoch 98/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 32.9465 - mean_absolute_error: 3.5013 - val_loss: 28.0423 - val_mean_absolute_error: 4.2645
# Epoch 99/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 28.4568 - mean_absolute_error: 3.5109 - val_loss: 27.5287 - val_mean_absolute_error: 4.1850
# Epoch 100/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 32.8631 - mean_absolute_error: 3.5389 - val_loss: 27.1094 - val_mean_absolute_error: 4.0659
# Epoch 101/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 31.4755 - mean_absolute_error: 3.4482 - val_loss: 27.1452 - val_mean_absolute_error: 4.0405
# Epoch 102/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 33.9943 - mean_absolute_error: 3.4999 - val_loss: 27.0503 - val_mean_absolute_error: 4.1144
# Epoch 103/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 34.0121 - mean_absolute_error: 3.5500 - val_loss: 26.9911 - val_mean_absolute_error: 4.0698
# Epoch 104/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 32.5883 - mean_absolute_error: 3.4595 - val_loss: 27.0774 - val_mean_absolute_error: 4.0337
# Epoch 105/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 33.8460 - mean_absolute_error: 3.4738 - val_loss: 27.1049 - val_mean_absolute_error: 4.0401
# Epoch 106/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 29.6654 - mean_absolute_error: 3.3501 - val_loss: 27.2123 - val_mean_absolute_error: 4.1061
# Epoch 107/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 34.1446 - mean_absolute_error: 3.5386 - val_loss: 27.1719 - val_mean_absolute_error: 4.1282
# Epoch 108/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 32.7307 - mean_absolute_error: 3.4765 - val_loss: 26.9671 - val_mean_absolute_error: 4.0346
# Epoch 109/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 31.2960 - mean_absolute_error: 3.4000 - val_loss: 26.8145 - val_mean_absolute_error: 4.0735
# Epoch 110/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 32.3204 - mean_absolute_error: 3.4331 - val_loss: 27.1783 - val_mean_absolute_error: 4.1977
# Epoch 111/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 30.7876 - mean_absolute_error: 3.4935 - val_loss: 26.8530 - val_mean_absolute_error: 4.1357
# Epoch 112/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 32.9458 - mean_absolute_error: 3.5786 - val_loss: 26.8125 - val_mean_absolute_error: 4.0597
# Epoch 113/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 30.4020 - mean_absolute_error: 3.4030 - val_loss: 26.8206 - val_mean_absolute_error: 4.1226
# Epoch 114/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 30.4835 - mean_absolute_error: 3.4231 - val_loss: 27.1515 - val_mean_absolute_error: 4.2027
# Epoch 115/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 31.1504 - mean_absolute_error: 3.4979 - val_loss: 26.7631 - val_mean_absolute_error: 4.1167
# Epoch 116/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 32.5032 - mean_absolute_error: 3.4423 - val_loss: 26.7851 - val_mean_absolute_error: 4.0489
# Epoch 117/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 33.4099 - mean_absolute_error: 3.5029 - val_loss: 26.6388 - val_mean_absolute_error: 4.0800
# Epoch 118/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 30.5778 - mean_absolute_error: 3.4067 - val_loss: 26.8177 - val_mean_absolute_error: 4.1557
# Epoch 119/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 30.7703 - mean_absolute_error: 3.4414 - val_loss: 26.9902 - val_mean_absolute_error: 4.1932
# Epoch 120/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 33.3100 - mean_absolute_error: 3.5432 - val_loss: 26.6427 - val_mean_absolute_error: 4.0972
# Epoch 121/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 29.3252 - mean_absolute_error: 3.3718 - val_loss: 26.6641 - val_mean_absolute_error: 4.0732
# Epoch 122/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 30.7182 - mean_absolute_error: 3.4536 - val_loss: 26.9832 - val_mean_absolute_error: 4.2021
# Epoch 123/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 33.2634 - mean_absolute_error: 3.5549 - val_loss: 26.9486 - val_mean_absolute_error: 4.1986
# Epoch 124/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 29.5036 - mean_absolute_error: 3.4021 - val_loss: 26.6662 - val_mean_absolute_error: 4.1334
# Epoch 125/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 33.5689 - mean_absolute_error: 3.5555 - val_loss: 26.8153 - val_mean_absolute_error: 4.1685
# Epoch 126/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 33.3983 - mean_absolute_error: 3.5331 - val_loss: 26.7152 - val_mean_absolute_error: 4.1334
# Epoch 127/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 30.4356 - mean_absolute_error: 3.4054 - val_loss: 26.7414 - val_mean_absolute_error: 4.1276
# Epoch 128/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 32.3722 - mean_absolute_error: 3.5007 - val_loss: 27.1263 - val_mean_absolute_error: 4.2251
# Epoch 129/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 32.0947 - mean_absolute_error: 3.5030 - val_loss: 27.1476 - val_mean_absolute_error: 4.2312
# Epoch 130/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 30.6408 - mean_absolute_error: 3.4931 - val_loss: 26.7308 - val_mean_absolute_error: 4.1475
# Epoch 131/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 32.9665 - mean_absolute_error: 3.4827 - val_loss: 26.5937 - val_mean_absolute_error: 4.1181
# Epoch 132/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 30.1250 - mean_absolute_error: 3.4098 - val_loss: 26.8661 - val_mean_absolute_error: 4.2030
# Epoch 133/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 30.1857 - mean_absolute_error: 3.4560 - val_loss: 27.6542 - val_mean_absolute_error: 4.3162
# Epoch 134/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 33.7972 - mean_absolute_error: 3.6640 - val_loss: 26.6468 - val_mean_absolute_error: 4.1804
# Epoch 135/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 33.4006 - mean_absolute_error: 3.5852 - val_loss: 26.5327 - val_mean_absolute_error: 4.0309
# Epoch 136/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 32.6218 - mean_absolute_error: 3.5804 - val_loss: 26.3200 - val_mean_absolute_error: 4.0357
# Epoch 137/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 27.9729 - mean_absolute_error: 3.3711 - val_loss: 28.3084 - val_mean_absolute_error: 4.3885
# Epoch 138/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 33.1787 - mean_absolute_error: 3.7124 - val_loss: 28.0794 - val_mean_absolute_error: 4.3623
# Epoch 139/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 31.9157 - mean_absolute_error: 3.5817 - val_loss: 26.3675 - val_mean_absolute_error: 4.0049
# Epoch 140/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 33.5427 - mean_absolute_error: 3.5825 - val_loss: 26.5600 - val_mean_absolute_error: 3.9812
# Epoch 141/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 31.2388 - mean_absolute_error: 3.5441 - val_loss: 26.6590 - val_mean_absolute_error: 4.2030
# Epoch 142/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 31.8063 - mean_absolute_error: 3.4944 - val_loss: 27.9736 - val_mean_absolute_error: 4.3537
# Epoch 143/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 31.7429 - mean_absolute_error: 3.6235 - val_loss: 26.0737 - val_mean_absolute_error: 4.1101
# Epoch 144/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 33.2709 - mean_absolute_error: 3.5542 - val_loss: 25.9345 - val_mean_absolute_error: 4.0094
# Epoch 145/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 31.7037 - mean_absolute_error: 3.4687 - val_loss: 25.8860 - val_mean_absolute_error: 4.0648
# Epoch 146/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 31.3725 - mean_absolute_error: 3.4421 - val_loss: 25.9689 - val_mean_absolute_error: 4.0850
# Epoch 147/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 31.4353 - mean_absolute_error: 3.4177 - val_loss: 25.7922 - val_mean_absolute_error: 4.0136
# Epoch 148/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 31.7248 - mean_absolute_error: 3.4552 - val_loss: 25.7379 - val_mean_absolute_error: 4.0379
# Epoch 149/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 28.7164 - mean_absolute_error: 3.3460 - val_loss: 26.7021 - val_mean_absolute_error: 4.2189
# Epoch 150/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 33.1280 - mean_absolute_error: 3.5576 - val_loss: 25.6437 - val_mean_absolute_error: 4.0572
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# MAE: 3.2252
# RMSE: 4.1055
# R²: 0.7692
# Adjusted R²: 0.7466
